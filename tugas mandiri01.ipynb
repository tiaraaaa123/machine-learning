# %%
import pandas as pd

# Data training
data = {
    'Temperatur': [10, 25, 15, 20, 18, 20, 22, 24],
    'Kecepatan': [0, 0, 5, 3, 7, 10, 5, 6],
    'Label': ['Dingin', 'Panas', 'Dingin', 'Panas', 'Dingin', 'Dingin', 'Panas', 'Panas']
}

df = pd.DataFrame(data)
df
# Out:
#    Temperatur  Kecepatan   Label
# 0          10          0  Dingin
# 1          25          0   Panas
# 2          15          5  Dingin
# 3          20          3   Panas
# 4          18          7  Dingin
# 5          20         10  Dingin
# 6          22          5   Panas
# 7          24          6   Panas

# %%
from sklearn.neighbors import KNeighborsClassifier

# fitur & label
X = df[['Temperatur', 'Kecepatan']]
y = df['Label']

# Model KNN dengan K = 3 (umum digunakan awal)
model = KNeighborsClassifier(n_neighbors=3)
model.fit(X, y)

# data test
test = [[16, 3]]
prediksi = model.predict(test)
prediksi
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(
# array(['Dingin'], dtype=object)

# %%
hasil = {}

max_k = len(X_train)

for k in range(1, max_k + 1):
    model = KNeighborsClassifier(n_neighbors=k)
    model.fit(X_train, y_train)
    pred = model.predict(X_test)
    acc = accuracy_score(y_test, pred)
    hasil[k] = acc

hasil
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-845539343.py in <cell line: 0>()
#       1 hasil = {}
#       2
# ----> 3 max_k = len(X_train)
#       4
#       5 for k in range(1, max_k + 1):
#
# NameError: name 'X_train' is not defined

# %%
best_k = max(hasil, key=hasil.get)
best_k, hasil[best_k]
